# %% [markdown]
# {
#
# "nbformat": 4,
#
# "nbformat\_minor": 0,
#
# "metadata": {
#
# "colab": {
#
# "name": "MUSHROOM\_PROJECT.ipynb",
#
# "provenance": \[\],
#
# "collapsed\_sections": \[\]
#
# },
#
# "kernelspec": {
#
# "name": "python3",
#
# "display\_name": "Python 3"
#
# },
#
# "language\_info": {
#
# "name": "python"
#
# }
#
# },
#
# "cells": \[
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "RRs8zwXXs6Bt"
#
# },
#
# "source": \[
#
# "import pandas as pd\\n",
#
# "import numpy as np\\n",
#
# "import matplotlib.pyplot as plt\\n",
#
# "import seaborn as sns\\n",
#
# "from sklearn.preprocessing import LabelEncoder\\n",
#
# "from sklearn.metrics import classification\_report, confusion\_matrix,
# accuracy\_score\\n",
#
# "from sklearn.model\_selection import train\_test\_split\\n",
#
# "from sklearn.ensemble import RandomForestClassifier\\n",
#
# "from sklearn.preprocessing import StandardScaler\\n",
#
# "from sklearn.tree import DecisionTreeClassifier\\n",
#
# "from sklearn.linear\_model import LogisticRegression\\n",
#
# "from sklearn.neighbors import KNeighborsClassifier\\n",
#
# "from sklearn.feature\_selection import SelectKBest,f\_classif\\n",
#
# "from sklearn.model\_selection import KFold, cross\_val\_score\\n",
#
# "\\n",
#
# "\\n",
#
# "\\n"
#
# \],
#
# "execution\_count": 229,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "resources": {
#
# "http://localhost:8080/nbextensions/google.colab/files.js": {
#
# "data":
# "...",
#
# "ok": true,
#
# "headers": \[
#
# \[
#
# "content-type",
#
# "application/javascript"
#
# \]
#
# \],
#
# "status": 200,
#
# "status\_text": ""
#
# }
#
# },
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 72
#
# },
#
# "id": "3RD34J80tCsS",
#
# "outputId": "c7952953-a44a-4778-bf58-63ad76bf53d8"
#
# },
#
# "source": \[
#
# "from google.colab import files\\n",
#
# "uploaded = files.upload()\\n"
#
# \],
#
# "execution\_count": 24,
#
# "outputs": \[
#
# {
#
# "output\_type": "display\_data",
#
# "data": {
#
# "text/html": \[
#
# "\\n",
#
# " \<input type=\\"file\\"
# id=\\"files-daa92a8e-e3b2-4a6a-8aa5-9d36cf2aa9cc\\" name=\\"files\[\]\\"
# multiple disabled\\n",
#
# " style=\\"border:none\\" /\>\\n",
#
# " \<output id=\\"result-daa92a8e-e3b2-4a6a-8aa5-9d36cf2aa9cc\\"\>\\n",
#
# " Upload widget is only available when the cell has been executed in
# the\\n",
#
# " current browser session. Please rerun this cell to enable.\\n",
#
# " \</output\>\\n",
#
# " \<script src=\\"/nbextensions/google.colab/files.js\\"\>\</script\> "
#
# \],
#
# "text/plain": \[
#
# "\<IPython.core.display.HTML object\>"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# }
#
# },
#
# {
#
# "output\_type": "stream",
#
# "text": \[
#
# "Saving mushrooms.csv to mushrooms.csv\\n"
#
# \],
#
# "name": "stdout"
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 490
#
# },
#
# "id": "oYs4NvnkuV0Z",
#
# "outputId": "2845d578-a0a9-4bcb-9cba-92e08b337aef"
#
# },
#
# "source": \[
#
# "df = pd.read\_csv('mushrooms.csv')\\n",
#
# "df"
#
# \],
#
# "execution\_count": 75,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>class\</th\>\\n",
#
# " \<th\>cap-shape\</th\>\\n",
#
# " \<th\>cap-surface\</th\>\\n",
#
# " \<th\>cap-color\</th\>\\n",
#
# " \<th\>bruises\</th\>\\n",
#
# " \<th\>odor\</th\>\\n",
#
# " \<th\>gill-attachment\</th\>\\n",
#
# " \<th\>gill-spacing\</th\>\\n",
#
# " \<th\>gill-size\</th\>\\n",
#
# " \<th\>gill-color\</th\>\\n",
#
# " \<th\>stalk-shape\</th\>\\n",
#
# " \<th\>stalk-root\</th\>\\n",
#
# " \<th\>stalk-surface-above-ring\</th\>\\n",
#
# " \<th\>stalk-surface-below-ring\</th\>\\n",
#
# " \<th\>stalk-color-above-ring\</th\>\\n",
#
# " \<th\>stalk-color-below-ring\</th\>\\n",
#
# " \<th\>veil-type\</th\>\\n",
#
# " \<th\>veil-color\</th\>\\n",
#
# " \<th\>ring-number\</th\>\\n",
#
# " \<th\>ring-type\</th\>\\n",
#
# " \<th\>spore-print-color\</th\>\\n",
#
# " \<th\>population\</th\>\\n",
#
# " \<th\>habitat\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>0\</th\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>u\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>1\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>g\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>2\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>l\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>m\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>3\</th\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>u\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>4\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>g\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>g\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>...\</th\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8119\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>?\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>l\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8120\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>?\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>v\</td\>\\n",
#
# " \<td\>l\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8121\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>?\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>l\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8122\</th\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>?\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>v\</td\>\\n",
#
# " \<td\>l\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8123\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>?\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>l\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\<p\>8124 rows × 23 columns\</p\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " class cap-shape cap-surface ... spore-print-color population
# habitat\\n",
#
# "0 p x s ... k s u\\n",
#
# "1 e x s ... n n g\\n",
#
# "2 e b s ... n n m\\n",
#
# "3 p x y ... k s u\\n",
#
# "4 e x s ... n a g\\n",
#
# "... ... ... ... ... ... ... ...\\n",
#
# "8119 e k s ... b c l\\n",
#
# "8120 e x s ... b v l\\n",
#
# "8121 e f s ... b c l\\n",
#
# "8122 p k y ... w v l\\n",
#
# "8123 e x s ... o c l\\n",
#
# "\\n",
#
# "\[8124 rows x 23 columns\]"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 75
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "tEzi6LY9y\_2v"
#
# },
#
# "source": \[
#
# "EDA\\n",
#
# "\\n"
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "XumGeDRVy-Bq"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "IW76XSH-v2Gg",
#
# "outputId": "4cbe8f70-d1a0-40f4-bfc9-162d15edfd07"
#
# },
#
# "source": \[
#
# "df.shape"
#
# \],
#
# "execution\_count": 31,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "(8124, 23)"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 31
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "CTJTsxvNz3vI"
#
# },
#
# "source": \[
#
# "There are 8124 rows and 23 columns."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 244
#
# },
#
# "id": "EbidAdK6zNyH",
#
# "outputId": "e61d7c4d-4f96-41c7-8ee4-c00bb4aded3a"
#
# },
#
# "source": \[
#
# "df.describe()"
#
# \],
#
# "execution\_count": 38,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>class\</th\>\\n",
#
# " \<th\>cap-shape\</th\>\\n",
#
# " \<th\>cap-surface\</th\>\\n",
#
# " \<th\>cap-color\</th\>\\n",
#
# " \<th\>bruises\</th\>\\n",
#
# " \<th\>odor\</th\>\\n",
#
# " \<th\>gill-attachment\</th\>\\n",
#
# " \<th\>gill-spacing\</th\>\\n",
#
# " \<th\>gill-size\</th\>\\n",
#
# " \<th\>gill-color\</th\>\\n",
#
# " \<th\>stalk-shape\</th\>\\n",
#
# " \<th\>stalk-root\</th\>\\n",
#
# " \<th\>stalk-surface-above-ring\</th\>\\n",
#
# " \<th\>stalk-surface-below-ring\</th\>\\n",
#
# " \<th\>stalk-color-above-ring\</th\>\\n",
#
# " \<th\>stalk-color-below-ring\</th\>\\n",
#
# " \<th\>veil-type\</th\>\\n",
#
# " \<th\>veil-color\</th\>\\n",
#
# " \<th\>ring-number\</th\>\\n",
#
# " \<th\>ring-type\</th\>\\n",
#
# " \<th\>spore-print-color\</th\>\\n",
#
# " \<th\>population\</th\>\\n",
#
# " \<th\>habitat\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>count\</th\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>unique\</th\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>10\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>9\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>12\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>9\</td\>\\n",
#
# " \<td\>9\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>9\</td\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>7\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>top\</th\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>v\</td\>\\n",
#
# " \<td\>d\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>freq\</th\>\\n",
#
# " \<td\>4208\</td\>\\n",
#
# " \<td\>3656\</td\>\\n",
#
# " \<td\>3244\</td\>\\n",
#
# " \<td\>2284\</td\>\\n",
#
# " \<td\>4748\</td\>\\n",
#
# " \<td\>3528\</td\>\\n",
#
# " \<td\>7914\</td\>\\n",
#
# " \<td\>6812\</td\>\\n",
#
# " \<td\>5612\</td\>\\n",
#
# " \<td\>1728\</td\>\\n",
#
# " \<td\>4608\</td\>\\n",
#
# " \<td\>3776\</td\>\\n",
#
# " \<td\>5176\</td\>\\n",
#
# " \<td\>4936\</td\>\\n",
#
# " \<td\>4464\</td\>\\n",
#
# " \<td\>4384\</td\>\\n",
#
# " \<td\>8124\</td\>\\n",
#
# " \<td\>7924\</td\>\\n",
#
# " \<td\>7488\</td\>\\n",
#
# " \<td\>3968\</td\>\\n",
#
# " \<td\>2388\</td\>\\n",
#
# " \<td\>4040\</td\>\\n",
#
# " \<td\>3148\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " class cap-shape cap-surface ... spore-print-color population
# habitat\\n",
#
# "count 8124 8124 8124 ... 8124 8124 8124\\n",
#
# "unique 2 6 4 ... 9 6 7\\n",
#
# "top e x y ... w v d\\n",
#
# "freq 4208 3656 3244 ... 2388 4040 3148\\n",
#
# "\\n",
#
# "\[4 rows x 23 columns\]"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 38
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "uPus2mR80Lgr"
#
# },
#
# "source": \[
#
# "There is no missing value in any column."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "WmapqT\_K0ahH",
#
# "outputId": "3c3efac7-49f8-4ca5-a78c-16bd1979191b"
#
# },
#
# "source": \[
#
# "df.dtypes"
#
# \],
#
# "execution\_count": 39,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "class object\\n",
#
# "cap-shape object\\n",
#
# "cap-surface object\\n",
#
# "cap-color object\\n",
#
# "bruises object\\n",
#
# "odor object\\n",
#
# "gill-attachment object\\n",
#
# "gill-spacing object\\n",
#
# "gill-size object\\n",
#
# "gill-color object\\n",
#
# "stalk-shape object\\n",
#
# "stalk-root object\\n",
#
# "stalk-surface-above-ring object\\n",
#
# "stalk-surface-below-ring object\\n",
#
# "stalk-color-above-ring object\\n",
#
# "stalk-color-below-ring object\\n",
#
# "veil-type object\\n",
#
# "veil-color object\\n",
#
# "ring-number object\\n",
#
# "ring-type object\\n",
#
# "spore-print-color object\\n",
#
# "population object\\n",
#
# "habitat object\\n",
#
# "dtype: object"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 39
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "5U3XFdiw0nsH"
#
# },
#
# "source": \[
#
# "All variables are object type. \\n",
#
# "The label(class) is a categorical variable. Thus, we will use
# classification algorithms. All independent variables are categorical, so
# there is no need to check for outliers."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "exGtSqod04v1",
#
# "outputId": "befd71de-b5f2-4848-8225-9200f8058e01"
#
# },
#
# "source": \[
#
# "df\['class'\].unique()"
#
# \],
#
# "execution\_count": 40,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\['p', 'e'\], dtype=object)"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 40
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "8ktZf4R21BoA"
#
# },
#
# "source": \[
#
# "There are two categories in the class column, i.e. 'p' and 'e'.\\n"
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "thk1k1YN1MEV",
#
# "outputId": "1bfc2361-4de4-40c7-f9c6-dd4897830df2"
#
# },
#
# "source": \[
#
# "df\['class'\].value\_counts()"
#
# \],
#
# "execution\_count": 41,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "e 4208\\n",
#
# "p 3916\\n",
#
# "Name: class, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 41
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "J8zDPt081SPt"
#
# },
#
# "source": \[
#
# "The dataset has 4208 edible mushrooms and 3916 poisonous mushrooms."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 248
#
# },
#
# "id": "MAHUw-Jm1U6d",
#
# "outputId": "824e3eba-c487-4103-cec7-5bfd53cc0646"
#
# },
#
# "source": \[
#
# "\#PIE CHART\\n",
#
# "\\n",
#
# "labels = 'edible','poisonous'\\n",
#
# "\\n",
#
# "fig, ax = plt.subplots()\\n",
#
# "ax.pie(df\['class'\].value\_counts(), labels = labels, autopct =
# '%1.2f%%', shadow = True)\\n",
#
# "\\n",
#
# "plt.show()"
#
# \],
#
# "execution\_count": 42,
#
# "outputs": \[
#
# {
#
# "output\_type": "display\_data",
#
# "data": {
#
# "image/png":
# "...\\n",
#
# "text/plain": \[
#
# "\<Figure size 432x288 with 1 Axes\>"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# }
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "ESClECEd1iN7"
#
# },
#
# "source": \[
#
# "This is the pie chart of the target column. The two categories are
# approximately equal, thus there is no problem of class imbalance."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "0RW1tdP11gsJ"
#
# },
#
# "source": \[
#
# "lab\_enc = LabelEncoder()"
#
# \],
#
# "execution\_count": 44,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "yTRFgn8b2JkR",
#
# "outputId": "d70d6973-e534-469d-a169-b81265f98ac7"
#
# },
#
# "source": \[
#
# "y = lab\_enc.fit\_transform(df\['class'\])\\n",
#
# "pd.Series(y)"
#
# \],
#
# "execution\_count": 132,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 1\\n",
#
# "1 0\\n",
#
# "2 0\\n",
#
# "3 1\\n",
#
# "4 0\\n",
#
# " ..\\n",
#
# "8119 0\\n",
#
# "8120 0\\n",
#
# "8121 0\\n",
#
# "8122 1\\n",
#
# "8123 0\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 132
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "IjxeSWyN2nXL"
#
# },
#
# "source": \[
#
# "The dependent variable is converted into numericals using label
# encoder. \\n",
#
# "p == 1, e == 0"
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "Zxd5D3aR2jt6"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 275
#
# },
#
# "id": "dl41drr32aIM",
#
# "outputId": "fe3ba27d-9e45-4b84-a3a4-0885a262da0b"
#
# },
#
# "source": \[
#
# "tar\_var = df\['class'\]\\n",
#
# "df.drop('class',axis = 1, inplace = True)\\n",
#
# "df.head()\\n"
#
# \],
#
# "execution\_count": 56,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>cap-shape\</th\>\\n",
#
# " \<th\>cap-surface\</th\>\\n",
#
# " \<th\>cap-color\</th\>\\n",
#
# " \<th\>bruises\</th\>\\n",
#
# " \<th\>odor\</th\>\\n",
#
# " \<th\>gill-attachment\</th\>\\n",
#
# " \<th\>gill-spacing\</th\>\\n",
#
# " \<th\>gill-size\</th\>\\n",
#
# " \<th\>gill-color\</th\>\\n",
#
# " \<th\>stalk-shape\</th\>\\n",
#
# " \<th\>stalk-root\</th\>\\n",
#
# " \<th\>stalk-surface-above-ring\</th\>\\n",
#
# " \<th\>stalk-surface-below-ring\</th\>\\n",
#
# " \<th\>stalk-color-above-ring\</th\>\\n",
#
# " \<th\>stalk-color-below-ring\</th\>\\n",
#
# " \<th\>veil-type\</th\>\\n",
#
# " \<th\>veil-color\</th\>\\n",
#
# " \<th\>ring-number\</th\>\\n",
#
# " \<th\>ring-type\</th\>\\n",
#
# " \<th\>spore-print-color\</th\>\\n",
#
# " \<th\>population\</th\>\\n",
#
# " \<th\>habitat\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>0\</th\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>u\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>1\</th\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>g\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>2\</th\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>l\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>m\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>3\</th\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>y\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>c\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>u\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>4\</th\>\\n",
#
# " \<td\>x\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>g\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>f\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>b\</td\>\\n",
#
# " \<td\>k\</td\>\\n",
#
# " \<td\>t\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>s\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>p\</td\>\\n",
#
# " \<td\>w\</td\>\\n",
#
# " \<td\>o\</td\>\\n",
#
# " \<td\>e\</td\>\\n",
#
# " \<td\>n\</td\>\\n",
#
# " \<td\>a\</td\>\\n",
#
# " \<td\>g\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " cap-shape cap-surface cap-color ... spore-print-color population
# habitat\\n",
#
# "0 x s n ... k s u\\n",
#
# "1 x s y ... n n g\\n",
#
# "2 b s w ... n n m\\n",
#
# "3 x y w ... k s u\\n",
#
# "4 x s g ... n a g\\n",
#
# "\\n",
#
# "\[5 rows x 22 columns\]"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 56
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "Gu-2mV-04XaU"
#
# },
#
# "source": \[
#
# "We have dropped the dependent variable."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 1000
#
# },
#
# "id": "EV6E3DgU4UyU",
#
# "outputId": "5c4ccdbd-b82b-4019-a600-41f1286ad87f"
#
# },
#
# "source": \[
#
# "plt.figure(figsize = (20,25),facecolor = 'white')\\n",
#
# "plotnumber = 1\\n",
#
# "\\n",
#
# "for column in df:\\n",
#
# " if plotnumber\<25:\\n",
#
# " ax = plt.subplot(5,5,plotnumber)\\n",
#
# " sns.stripplot(y,df\[column\])\\n",
#
# " plotnumber += 1\\n",
#
# "plt.tight\_layout()"
#
# \],
#
# "execution\_count": 80,
#
# "outputs": \[
#
# {
#
# "output\_type": "stream",
#
# "text": \[
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n",
#
# "/usr/local/lib/python3.7/dist-packages/seaborn/\_decorators.py:43:
# FutureWarning: Pass the following variables as keyword args: x, y. From
# version 0.12, the only valid positional argument will be \`data\`, and
# passing other arguments without an explicit keyword will result in an
# error or misinterpretation.\\n",
#
# " FutureWarning\\n"
#
# \],
#
# "name": "stderr"
#
# },
#
# {
#
# "output\_type": "display\_data",
#
# "data": {
#
# "image/png":
# "...\\n",
#
# "text/plain": \[
#
# "\<Figure size 1440x1800 with 23 Axes\>"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# }
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "96FyA7dJ6VM5"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": 69,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "JeiPjkh-JFg6"
#
# },
#
# "source": \[
#
# "The above graphical representation shows how the features are scattered
# across the label. \\n",
#
# "We can interpret that odor is an important feature as it differentiates
# the edibility across all the categories of odor.\\n",
#
# "Apart from this, we are able to get insights of different categories
# using the above graph.\\n",
#
# "But there are also some features that do not help us to differentiate
# between edible and poisonous, for example: stalk-surface-above-ring,
# stalk-surface-below-ring, etc."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "jarl2vxv78f6"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": 71,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "41pWJ2m0KydG"
#
# },
#
# "source": \[
#
# "SO, LETS USE ODOR, STALK-COLOR-ABOVE-RING, STALK-COLOR-ABOVE-RING,
# VEIL-COLOR TO DISCRIMINATE BETWEEN EDIBLE MISHROOM AND POISONOUS
# MUSHROOM. We will use logistic regression."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "3mndiK3n9wSQ",
#
# "outputId": "266276bb-2178-4623-d839-cd09c4830342"
#
# },
#
# "source": \[
#
# "lab\_enc\_f1 = LabelEncoder()\\n",
#
# "\\n",
#
# "f1 = lab\_enc\_f1.fit\_transform(df\['odor'\])\\n",
#
# "pd.Series(f1)"
#
# \],
#
# "execution\_count": 106,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 6\\n",
#
# "1 0\\n",
#
# "2 3\\n",
#
# "3 6\\n",
#
# "4 5\\n",
#
# " ..\\n",
#
# "8119 5\\n",
#
# "8120 5\\n",
#
# "8121 5\\n",
#
# "8122 8\\n",
#
# "8123 5\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 106
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "CNwKY7T7-Zyl"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": 98,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "x7UqtChFUH4K"
#
# },
#
# "source": \[
#
# "We have converted the odor column into numerical data using label
# encoder."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "oVu\_xJWmUNHy",
#
# "outputId": "fd474ab5-99bf-423d-d637-19a2e2726645"
#
# },
#
# "source": \[
#
# "lab\_enc\_f2 = LabelEncoder()\\n",
#
# "\\n",
#
# "f2 = lab\_enc\_f2.fit\_transform(df\['stalk-surface-above-ring'\])\\n",
#
# "pd.Series(f2)"
#
# \],
#
# "execution\_count": 103,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 2\\n",
#
# "1 2\\n",
#
# "2 2\\n",
#
# "3 2\\n",
#
# "4 2\\n",
#
# " ..\\n",
#
# "8119 2\\n",
#
# "8120 2\\n",
#
# "8121 2\\n",
#
# "8122 2\\n",
#
# "8123 2\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 103
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "LqVvjy2KPHdQ",
#
# "outputId": "0b193017-cb3a-4a23-d474-a0a5518ea182"
#
# },
#
# "source": \[
#
# "lab\_enc\_f3 = LabelEncoder()\\n",
#
# "\\n",
#
# "f3 = lab\_enc\_f3.fit\_transform(df\['stalk-surface-below-ring'\])\\n",
#
# "pd.Series(f3)\\n"
#
# \],
#
# "execution\_count": 104,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 2\\n",
#
# "1 2\\n",
#
# "2 2\\n",
#
# "3 2\\n",
#
# "4 2\\n",
#
# " ..\\n",
#
# "8119 2\\n",
#
# "8120 2\\n",
#
# "8121 2\\n",
#
# "8122 1\\n",
#
# "8123 2\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 104
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "8FoMAqJ6PuLH",
#
# "outputId": "4135b901-da75-4eab-c21a-2f0da53f8c32"
#
# },
#
# "source": \[
#
# "lab\_enc\_f4 = LabelEncoder()\\n",
#
# "\\n",
#
# "f4 = lab\_enc\_f4.fit\_transform(df\['veil-color'\])\\n",
#
# "pd.Series(f4)"
#
# \],
#
# "execution\_count": 105,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 2\\n",
#
# "1 2\\n",
#
# "2 2\\n",
#
# "3 2\\n",
#
# "4 2\\n",
#
# " ..\\n",
#
# "8119 1\\n",
#
# "8120 0\\n",
#
# "8121 1\\n",
#
# "8122 2\\n",
#
# "8123 1\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 105
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "rh2Y6UTcQI\_h"
#
# },
#
# "source": \[
#
# "\\n",
#
# "\\n",
#
# "---\\n",
#
# "\\n"
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 419
#
# },
#
# "id": "wkaZUPW9W\_by",
#
# "outputId": "c7302962-a479-420b-a2cc-84f454d63aec"
#
# },
#
# "source": \[
#
# "i = pd.DataFrame({})\\n",
#
# "i\['odor'\] = f1\\n",
#
# "i\['stalk color above ring'\] = f2\\n",
#
# "i\['stalk color below ring'\] = f3\\n",
#
# "i\['veil color'\] = f4\\n",
#
# "i"
#
# \],
#
# "execution\_count": 107,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>odor\</th\>\\n",
#
# " \<th\>stalk color above ring\</th\>\\n",
#
# " \<th\>stalk color below ring\</th\>\\n",
#
# " \<th\>veil color\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>0\</th\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>1\</th\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>2\</th\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>3\</th\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>4\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>...\</th\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8119\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8120\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8121\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8122\</th\>\\n",
#
# " \<td\>8\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8123\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\<p\>8124 rows × 4 columns\</p\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " odor stalk color above ring stalk color below ring veil color\\n",
#
# "0 6 2 2 2\\n",
#
# "1 0 2 2 2\\n",
#
# "2 3 2 2 2\\n",
#
# "3 6 2 2 2\\n",
#
# "4 5 2 2 2\\n",
#
# "... ... ... ... ...\\n",
#
# "8119 5 2 2 1\\n",
#
# "8120 5 2 2 0\\n",
#
# "8121 5 2 2 1\\n",
#
# "8122 8 2 1 2\\n",
#
# "8123 5 2 2 1\\n",
#
# "\\n",
#
# "\[8124 rows x 4 columns\]"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 107
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "z1kK9SrDQFuk"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "jpt6NRwXQH60"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "-QJ8ng\_7QBtD"
#
# },
#
# "source": \[
#
# "scalar = StandardScaler()\\n",
#
# "x\_scaled = scalar.fit\_transform(i)"
#
# \],
#
# "execution\_count": 108,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "-aAe04QCQRSK",
#
# "outputId": "21b94311-68ad-4440-c97f-baf5142ff755"
#
# },
#
# "source": \[
#
# "x\_scaled"
#
# \],
#
# "execution\_count": 109,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[\[ 0.88193766, 0.68377765, 0.58638466, 0.14203663\],\\n",
#
# " \[-1.97031615, 0.68377765, 0.58638466, 0.14203663\],\\n",
#
# " \[-0.54418924, 0.68377765, 0.58638466, 0.14203663\],\\n",
#
# " ...,\\n",
#
# " \[ 0.40656203, 0.68377765, 0.58638466, -3.97905487\],\\n",
#
# " \[ 1.83268894, 0.68377765, -0.89305291, 0.14203663\],\\n",
#
# " \[ 0.40656203, 0.68377765, 0.58638466, -3.97905487\]\])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 109
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "kUAkmVndQTd3"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": 93,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "nWd9xMkdQyoQ"
#
# },
#
# "source": \[
#
# "x\_train,x\_test,y\_train,y\_test = train\_test\_split(x\_scaled, y,
# test\_size = 0.25, random\_state = 1)"
#
# \],
#
# "execution\_count": 110,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "J\_czcIgLQ3Cw",
#
# "outputId": "0dacd595-b44d-425b-cb76-2fb119c9190f"
#
# },
#
# "source": \[
#
# "log\_reg = LogisticRegression()\\n",
#
# "\\n",
#
# "log\_reg.fit(x\_train,y\_train)"
#
# \],
#
# "execution\_count": 111,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "LogisticRegression(C=1.0, class\_weight=None, dual=False,
# fit\_intercept=True,\\n",
#
# " intercept\_scaling=1, l1\_ratio=None, max\_iter=100,\\n",
#
# " multi\_class='auto', n\_jobs=None, penalty='l2',\\n",
#
# " random\_state=None, solver='lbfgs', tol=0.0001, verbose=0,\\n",
#
# " warm\_start=False)"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 111
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "2Wt0PqvYRDNA"
#
# },
#
# "source": \[
#
# "import pickle\\n",
#
# "with open('modelForPrediction.sav','wb') as f:\\n",
#
# " pickle.dump(scalar,f)\\n",
#
# "\\n",
#
# "with open('StandardScaler.sav', 'wb') as f:\\n",
#
# " pickle.dump(scalar,f)\\n",
#
# "\\n",
#
# "y\_pred = log\_reg.predict(x\_test)\\n"
#
# \],
#
# "execution\_count": 112,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "y6KFQaRCR0U1",
#
# "outputId": "bc4faf2f-a3cd-4ed2-eab8-e8ee442f2117"
#
# },
#
# "source": \[
#
# "print(classification\_report(y\_pred,y\_test))\\n"
#
# \],
#
# "execution\_count": 113,
#
# "outputs": \[
#
# {
#
# "output\_type": "stream",
#
# "text": \[
#
# " precision recall f1-score support\\n",
#
# "\\n",
#
# " 0 0.82 0.70 0.75 1187\\n",
#
# " 1 0.65 0.78 0.71 844\\n",
#
# "\\n",
#
# " accuracy 0.73 2031\\n",
#
# " macro avg 0.73 0.74 0.73 2031\\n",
#
# "weighted avg 0.75 0.73 0.73 2031\\n",
#
# "\\n"
#
# \],
#
# "name": "stdout"
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "1Yw3ymz8Sboo",
#
# "outputId": "e2d7952b-f5c8-4ce2-b117-3906f403ff84"
#
# },
#
# "source": \[
#
# "confusion\_matrix(y\_test,y\_pred)"
#
# \],
#
# "execution\_count": 114,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[\[832, 188\],\\n",
#
# " \[355, 656\]\])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 114
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "Z78DCtczZFuh",
#
# "outputId": "7c2e4552-feb9-468b-d5b8-f3dc2597c4f5"
#
# },
#
# "source": \[
#
# "\#Applying cross validation technique:\\n",
#
# "\\n",
#
# "k\_f\_ = KFold(n\_splits = 3, shuffle = True)\\n",
#
# "k\_f\_\\n",
#
# "\\n",
#
# "\\n"
#
# \],
#
# "execution\_count": 301,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "KFold(n\_splits=3, random\_state=None, shuffle=True)"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 301
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "cVot1nXA8GWM"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "FUQ8iCl1A1iB",
#
# "outputId": "6730dd66-50cc-4fed-fa13-f753d291dcbe"
#
# },
#
# "source": \[
#
# "cross\_val\_score(log\_reg,i,y,cv = 8)\\n"
#
# \],
#
# "execution\_count": 307,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[0.61220472, 0.79822835, 0.68700787, 0.78641732,
# 0.81477833,\\n",
#
# " 0.72019704, 0.63842365, 0.55960591\])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 307
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "DQaTv1HVBun-",
#
# "outputId": "efffbc8d-4618-4825-f5d9-6bc3a856875d"
#
# },
#
# "source": \[
#
# "cross\_val\_score(log\_reg,i,y,cv = 8).mean()"
#
# \],
#
# "execution\_count": 308,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.7021078992281137"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 308
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "t213basoB09M",
#
# "outputId": "1f2c6e30-1ef2-44b6-a36f-2ca453f6d55d"
#
# },
#
# "source": \[
#
# "\#Difference between the accuracy score of logistic regression and the
# cross validation score is:\\n",
#
# "\\n",
#
# "log\_ref\_diff = 0.73 - 0.7021078992281137\\n",
#
# "log\_ref\_diff"
#
# \],
#
# "execution\_count": 309,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.027892100771886308"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 309
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "7ytvhgXhZYTk",
#
# "outputId": "ce63c4db-acf3-4784-cd23-cad776b73370"
#
# },
#
# "source": \[
#
# "i\['odor'\].value\_counts()\\n"
#
# \],
#
# "execution\_count": 120,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "5 3528\\n",
#
# "2 2160\\n",
#
# "7 576\\n",
#
# "8 576\\n",
#
# "3 400\\n",
#
# "0 400\\n",
#
# "6 256\\n",
#
# "1 192\\n",
#
# "4 36\\n",
#
# "Name: odor, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 120
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "vTnxAeDBZtzf",
#
# "outputId": "89390881-6f58-431d-98b6-29e6a328497e"
#
# },
#
# "source": \[
#
# "i\['stalk color above ring'\].value\_counts()\\n"
#
# \],
#
# "execution\_count": 123,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "2 5176\\n",
#
# "1 2372\\n",
#
# "0 552\\n",
#
# "3 24\\n",
#
# "Name: stalk color above ring, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 123
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "esTlxKTvaC57",
#
# "outputId": "028c9ec8-fccf-42b2-d9ad-02cd96f46c7c"
#
# },
#
# "source": \[
#
# "i\['stalk color below ring'\].value\_counts()\\n"
#
# \],
#
# "execution\_count": 124,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "2 4936\\n",
#
# "1 2304\\n",
#
# "0 600\\n",
#
# "3 284\\n",
#
# "Name: stalk color below ring, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 124
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "hm5rfU\_9aHQM",
#
# "outputId": "f8e94149-2aa7-432f-8b72-bcd915fb645a"
#
# },
#
# "source": \[
#
# "i\['veil color'\].value\_counts()"
#
# \],
#
# "execution\_count": 125,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "2 7924\\n",
#
# "1 96\\n",
#
# "0 96\\n",
#
# "3 8\\n",
#
# "Name: veil color, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 125
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "7d9xbBvraLCF"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "yO6VQOfPaXwk"
#
# },
#
# "source": \[
#
# "From the above 4 counts we can see that the model has class imbalance
# in case of veil color. So, we will drop the feature veil color."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "D\_I-yCNSbD6Q"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "FKcvQQJYbEkl"
#
# },
#
# "source": \[
#
# "WE WILL USE ODOR, STALK-COLOR-ABOVE-RING, STALK-COLOR-ABOVE-RING TO
# DISCRIMINATE BETWEEN EDIBLE MISHROOM AND POISONOUS MUSHROOM. We will use
# Decision Tree."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 419
#
# },
#
# "id": "3-7rNP8wbK53",
#
# "outputId": "e7ad6f67-771b-4fe8-9d20-2aecb11f1014"
#
# },
#
# "source": \[
#
# "j = pd.DataFrame({})\\n",
#
# "j\['odor'\] = f1\\n",
#
# "j\['stalk color above ring'\] = f2\\n",
#
# "j\['stalk color below ring'\] = f3\\n",
#
# "\\n",
#
# "j"
#
# \],
#
# "execution\_count": 127,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>odor\</th\>\\n",
#
# " \<th\>stalk color above ring\</th\>\\n",
#
# " \<th\>stalk color below ring\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>0\</th\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>1\</th\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>2\</th\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>3\</th\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>4\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>...\</th\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8119\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8120\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8121\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8122\</th\>\\n",
#
# " \<td\>8\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8123\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\<p\>8124 rows × 3 columns\</p\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " odor stalk color above ring stalk color below ring\\n",
#
# "0 6 2 2\\n",
#
# "1 0 2 2\\n",
#
# "2 3 2 2\\n",
#
# "3 6 2 2\\n",
#
# "4 5 2 2\\n",
#
# "... ... ... ...\\n",
#
# "8119 5 2 2\\n",
#
# "8120 5 2 2\\n",
#
# "8121 5 2 2\\n",
#
# "8122 8 2 1\\n",
#
# "8123 5 2 2\\n",
#
# "\\n",
#
# "\[8124 rows x 3 columns\]"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 127
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "0K4M4iH7bqpH"
#
# },
#
# "source": \[
#
# "\\n"
#
# \],
#
# "execution\_count": 128,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "Ihcf6fuWb2\_Z"
#
# },
#
# "source": \[
#
# "x\_train,x\_test,y\_train,y\_test = train\_test\_split(j,y,test\_size
# =0.25,random\_state = 20)"
#
# \],
#
# "execution\_count": 135,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "4ktNlkhbcR9u",
#
# "outputId": "d4a28184-68ff-4c7c-b9c4-bc54f7f22fbb"
#
# },
#
# "source": \[
#
# "clf = DecisionTreeClassifier()\\n",
#
# "clf.fit(x\_train,y\_train)\\n"
#
# \],
#
# "execution\_count": 137,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "DecisionTreeClassifier(ccp\_alpha=0.0, class\_weight=None,
# criterion='gini',\\n",
#
# " max\_depth=None, max\_features=None, max\_leaf\_nodes=None,\\n",
#
# " min\_impurity\_decrease=0.0, min\_impurity\_split=None,\\n",
#
# " min\_samples\_leaf=1, min\_samples\_split=2,\\n",
#
# " min\_weight\_fraction\_leaf=0.0, presort='deprecated',\\n",
#
# " random\_state=None, splitter='best')"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 137
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "0MX8HmYKdedg",
#
# "outputId": "378efbfd-9c13-422e-b206-140539077f83"
#
# },
#
# "source": \[
#
# "clf.score(x\_train,y\_train)"
#
# \],
#
# "execution\_count": 155,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.9891678975873953"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 155
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "OCpFDYZbgWun"
#
# },
#
# "source": \[
#
# "y\_pred = clf.predict(x\_test)"
#
# \],
#
# "execution\_count": 156,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "AunoM4mAgnit",
#
# "outputId": "cf0eef34-e0a2-49a6-d087-2fc3861a95fe"
#
# },
#
# "source": \[
#
# "clf.score(x\_test,y\_test)"
#
# \],
#
# "execution\_count": 157,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.9891678975873953"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 157
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "QqlwYHkHhDIG",
#
# "outputId": "4eb75eda-ed1f-4187-ea1a-31ee3b9133e6"
#
# },
#
# "source": \[
#
# "confusion\_matrix(y\_test,y\_pred)"
#
# \],
#
# "execution\_count": 158,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[\[1062, 0\],\\n",
#
# " \[ 22, 947\]\])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 158
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "qQjWaAU9hQDJ",
#
# "outputId": "f8d5eb09-1129-4615-a5fd-e67e5b2aef70"
#
# },
#
# "source": \[
#
# "print(classification\_report(y\_test,y\_pred))"
#
# \],
#
# "execution\_count": 160,
#
# "outputs": \[
#
# {
#
# "output\_type": "stream",
#
# "text": \[
#
# " precision recall f1-score support\\n",
#
# "\\n",
#
# " 0 0.98 1.00 0.99 1062\\n",
#
# " 1 1.00 0.98 0.99 969\\n",
#
# "\\n",
#
# " accuracy 0.99 2031\\n",
#
# " macro avg 0.99 0.99 0.99 2031\\n",
#
# "weighted avg 0.99 0.99 0.99 2031\\n",
#
# "\\n"
#
# \],
#
# "name": "stdout"
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "Mfx64R8xiUP6",
#
# "outputId": "53397ef7-4c15-4e48-edd0-c769caa310de"
#
# },
#
# "source": \[
#
# "\#Applying cross validation technique to decision tree:\\n",
#
# "\\n",
#
# "k\_f1 = KFold(n\_splits = 3,shuffle = True)\\n",
#
# "k\_f1"
#
# \],
#
# "execution\_count": 311,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "KFold(n\_splits=3, random\_state=None, shuffle=True)"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 311
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "YWZnH4Sgn\_gc",
#
# "outputId": "672be8f0-8c3e-4e2c-fe68-82922ecc1877"
#
# },
#
# "source": \[
#
# "cross\_val\_score(clf, j, y)"
#
# \],
#
# "execution\_count": 328,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[0.84184615, 0.99507692, 0.95630769, 1. , 0.99014778\])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 328
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "IlbD4c6gobL8",
#
# "outputId": "c1ad82dd-3ce3-4ec0-a872-fab0024ed8a0"
#
# },
#
# "source": \[
#
# "cross\_val\_score(clf, j, y).mean()"
#
# \],
#
# "execution\_count": 326,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.957660932171277"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 326
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "zs1KmySJAFmO",
#
# "outputId": "b23c6861-97cb-4131-cc27-fee9726012fc"
#
# },
#
# "source": \[
#
# "\#Difference between the accuracy rate of Decision Tree Classifier and
# the cross validation score is:\\n",
#
# "DT\_diff = 0.99 - 0.957660932171277\\n",
#
# "DT\_diff"
#
# \],
#
# "execution\_count": 329,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.03233906782872298"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 329
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "6Lh1b8mwow5N"
#
# },
#
# "source": \[
#
# "Now, we will use K Nearest Neighbors to find the edibility of the
# mushrooms. "
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "XDnQhGDApFyw",
#
# "outputId": "d28ab776-ac04-469d-cc05-d3ff41b074a8"
#
# },
#
# "source": \[
#
# "lab\_enc\_f5 = LabelEncoder()\\n",
#
# "\\n",
#
# "f5 = lab\_enc\_f5.fit\_transform(df\['cap-shape'\])\\n",
#
# "pd.Series(f5)\\n"
#
# \],
#
# "execution\_count": 189,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 5\\n",
#
# "1 5\\n",
#
# "2 0\\n",
#
# "3 5\\n",
#
# "4 5\\n",
#
# " ..\\n",
#
# "8119 3\\n",
#
# "8120 5\\n",
#
# "8121 2\\n",
#
# "8122 3\\n",
#
# "8123 5\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 189
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "B0CTn1iEpKnx",
#
# "outputId": "5cca72e3-797c-4d24-c26d-76228e0666bf"
#
# },
#
# "source": \[
#
# "lab\_enc\_f6 = LabelEncoder()\\n",
#
# "\\n",
#
# "f6 = lab\_enc\_f6.fit\_transform(df\['cap-surface'\])\\n",
#
# "pd.Series(f6)"
#
# \],
#
# "execution\_count": 190,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 2\\n",
#
# "1 2\\n",
#
# "2 2\\n",
#
# "3 3\\n",
#
# "4 2\\n",
#
# " ..\\n",
#
# "8119 2\\n",
#
# "8120 2\\n",
#
# "8121 2\\n",
#
# "8122 3\\n",
#
# "8123 2\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 190
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "-o9KdSPiwoSG",
#
# "outputId": "8dcdee90-4de1-491f-bbb6-110a9cb0a412"
#
# },
#
# "source": \[
#
# "lab\_enc\_f7 = LabelEncoder()\\n",
#
# "\\n",
#
# "f7 = lab\_enc\_f7.fit\_transform(df\['cap-color'\])\\n",
#
# "pd.Series(f7)"
#
# \],
#
# "execution\_count": 191,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 4\\n",
#
# "1 9\\n",
#
# "2 8\\n",
#
# "3 8\\n",
#
# "4 3\\n",
#
# " ..\\n",
#
# "8119 4\\n",
#
# "8120 4\\n",
#
# "8121 4\\n",
#
# "8122 4\\n",
#
# "8123 4\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 191
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "rFXYN8X3xRj6",
#
# "outputId": "7481a215-c765-4a77-cea8-2efd1f5929a9"
#
# },
#
# "source": \[
#
# "lab\_enc\_f8 = LabelEncoder()\\n",
#
# "\\n",
#
# "f8 = lab\_enc\_f8.fit\_transform(df\['gill-color'\])\\n",
#
# "pd.Series(f8)"
#
# \],
#
# "execution\_count": 192,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 4\\n",
#
# "1 4\\n",
#
# "2 5\\n",
#
# "3 5\\n",
#
# "4 4\\n",
#
# " ..\\n",
#
# "8119 11\\n",
#
# "8120 11\\n",
#
# "8121 5\\n",
#
# "8122 0\\n",
#
# "8123 11\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 192
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "ftIMyWHqyIyc",
#
# "outputId": "8fbcb6b3-dfdd-40ed-f275-18a72c11c812"
#
# },
#
# "source": \[
#
# "lab\_enc\_f9 = LabelEncoder()\\n",
#
# "\\n",
#
# "f9 = lab\_enc\_f9.fit\_transform(df\['stalk-root'\])\\n",
#
# "pd.Series(f9)"
#
# \],
#
# "execution\_count": 193,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 3\\n",
#
# "1 2\\n",
#
# "2 2\\n",
#
# "3 3\\n",
#
# "4 3\\n",
#
# " ..\\n",
#
# "8119 0\\n",
#
# "8120 0\\n",
#
# "8121 0\\n",
#
# "8122 0\\n",
#
# "8123 0\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 193
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "BrXjNrlUyMlL"
#
# },
#
# "source": \[
#
# "\\n"
#
# \],
#
# "execution\_count": 200,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "Msihwk4jz5r5",
#
# "outputId": "9c6b215e-7d32-40a9-d58a-6fc5c8cab51c"
#
# },
#
# "source": \[
#
# "lab\_enc\_f10 = LabelEncoder()\\n",
#
# "\\n",
#
# "f10 = lab\_enc\_f10.fit\_transform(df\['ring-type'\])\\n",
#
# "pd.Series(f10)"
#
# \],
#
# "execution\_count": 201,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 4\\n",
#
# "1 4\\n",
#
# "2 4\\n",
#
# "3 4\\n",
#
# "4 0\\n",
#
# " ..\\n",
#
# "8119 4\\n",
#
# "8120 4\\n",
#
# "8121 4\\n",
#
# "8122 0\\n",
#
# "8123 4\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 201
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "uBZ8WPrG0NcS"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "jm3hL7B-0Q5X",
#
# "outputId": "da2d6b74-29bc-41e6-90c4-d397abb2ef56"
#
# },
#
# "source": \[
#
# "lab\_enc\_f11 = LabelEncoder()\\n",
#
# "\\n",
#
# "f11 = lab\_enc\_f11.fit\_transform(df\['spore-print-color'\])\\n",
#
# "pd.Series(f11)"
#
# \],
#
# "execution\_count": 202,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 2\\n",
#
# "1 3\\n",
#
# "2 3\\n",
#
# "3 2\\n",
#
# "4 3\\n",
#
# " ..\\n",
#
# "8119 0\\n",
#
# "8120 0\\n",
#
# "8121 0\\n",
#
# "8122 7\\n",
#
# "8123 4\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 202
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "2Q0sIqyv0h35",
#
# "outputId": "9d6cf872-716c-4994-c6d9-1306d121cc33"
#
# },
#
# "source": \[
#
# "lab\_enc\_f12 = LabelEncoder()\\n",
#
# "\\n",
#
# "f12 = lab\_enc\_f12.fit\_transform(df\['population'\])\\n",
#
# "pd.Series(f12)"
#
# \],
#
# "execution\_count": 203,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 3\\n",
#
# "1 2\\n",
#
# "2 2\\n",
#
# "3 3\\n",
#
# "4 0\\n",
#
# " ..\\n",
#
# "8119 1\\n",
#
# "8120 4\\n",
#
# "8121 1\\n",
#
# "8122 4\\n",
#
# "8123 1\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 203
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "Oo3ir3pT0qeb",
#
# "outputId": "5422f742-c195-48c4-f4c6-35b335e87dc6"
#
# },
#
# "source": \[
#
# "lab\_enc\_f13 = LabelEncoder()\\n",
#
# "\\n",
#
# "f13 = lab\_enc\_f13.fit\_transform(df\['habitat'\])\\n",
#
# "pd.Series(f13)"
#
# \],
#
# "execution\_count": 204,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0 5\\n",
#
# "1 1\\n",
#
# "2 3\\n",
#
# "3 5\\n",
#
# "4 1\\n",
#
# " ..\\n",
#
# "8119 2\\n",
#
# "8120 2\\n",
#
# "8121 2\\n",
#
# "8122 2\\n",
#
# "8123 2\\n",
#
# "Length: 8124, dtype: int64"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 204
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "uA878vs65Hci"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "9psYmlHr5Jem"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "b\_cJFbT35J35"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "bUUwtMrl5KOX"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "NWUF1B3N5KiL"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "juQ0b3tR5LBW"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "qES-XjGU5LVL"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "mH0A0G085Lsw"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "MOmAFMHk5MFS"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 436
#
# },
#
# "id": "SL0NnZBZ0wFM",
#
# "outputId": "5fe866a8-32c9-446a-fde5-88485f092bf8"
#
# },
#
# "source": \[
#
# "k = pd.DataFrame({})\\n",
#
# "k\['odor'\] = f1\\n",
#
# "k\['stalk color above ring'\] = f2\\n",
#
# "k\['stalk color below ring'\] = f3\\n",
#
# "k\['veil color'\] = f4\\n",
#
# "k\['cap-shape'\] = f5\\n",
#
# "k\['cap-surface'\] = f6\\n",
#
# "k\['cap-color'\] = f7\\n",
#
# "k\['gill-color'\] = f8\\n",
#
# "k\['stalk-root'\] = f9\\n",
#
# "k\['ring-type'\] = f10\\n",
#
# "k\['spore-print-color'\] = f11\\n",
#
# "k\['population'\] = f12\\n",
#
# "k\['habitat'\] = f13\\n",
#
# "k"
#
# \],
#
# "execution\_count": 206,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>odor\</th\>\\n",
#
# " \<th\>stalk color above ring\</th\>\\n",
#
# " \<th\>stalk color below ring\</th\>\\n",
#
# " \<th\>veil color\</th\>\\n",
#
# " \<th\>cap-shape\</th\>\\n",
#
# " \<th\>cap-surface\</th\>\\n",
#
# " \<th\>cap-color\</th\>\\n",
#
# " \<th\>gill-color\</th\>\\n",
#
# " \<th\>stalk-root\</th\>\\n",
#
# " \<th\>ring-type\</th\>\\n",
#
# " \<th\>spore-print-color\</th\>\\n",
#
# " \<th\>population\</th\>\\n",
#
# " \<th\>habitat\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>0\</th\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>1\</th\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>9\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>2\</th\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>8\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>3\</th\>\\n",
#
# " \<td\>6\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>8\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>4\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>...\</th\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8119\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>11\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8120\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>11\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8121\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8122\</th\>\\n",
#
# " \<td\>8\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>7\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8123\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>11\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\<p\>8124 rows × 13 columns\</p\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " odor stalk color above ring ... population habitat\\n",
#
# "0 6 2 ... 3 5\\n",
#
# "1 0 2 ... 2 1\\n",
#
# "2 3 2 ... 2 3\\n",
#
# "3 6 2 ... 3 5\\n",
#
# "4 5 2 ... 0 1\\n",
#
# "... ... ... ... ... ...\\n",
#
# "8119 5 2 ... 1 2\\n",
#
# "8120 5 2 ... 4 2\\n",
#
# "8121 5 2 ... 1 2\\n",
#
# "8122 8 2 ... 4 2\\n",
#
# "8123 5 2 ... 1 2\\n",
#
# "\\n",
#
# "\[8124 rows x 13 columns\]"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 206
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "sWEn\_VNx2aFB",
#
# "outputId": "f5d87848-16c8-4e56-8608-2f39a666d83c"
#
# },
#
# "source": \[
#
# "best\_features = SelectKBest(score\_func = f\_classif, k = 6)\\n",
#
# "\\n",
#
# "fit = best\_features.fit(k,y)\\n",
#
# "\\n",
#
# "df\_scores = pd.DataFrame(fit.scores\_)\\n",
#
# "\\n",
#
# "df\_columns = pd.DataFrame(k.columns)\\n",
#
# "\\n",
#
# "feature\_scores = pd.concat(\[df\_columns, df\_scores\],axis = 1)\\n",
#
# "\\n",
#
# "feature\_scores.columns = (\['Feature\_Name', 'Score'\])\\n",
#
# "\\n",
#
# "print(feature\_scores.nlargest(6,'Score'))"
#
# \],
#
# "execution\_count": 215,
#
# "outputs": \[
#
# {
#
# "output\_type": "stream",
#
# "text": \[
#
# " Feature\_Name Score\\n",
#
# "7 gill-color 3182.113373\\n",
#
# "9 ring-type 1658.306456\\n",
#
# "8 stalk-root 1365.372974\\n",
#
# "1 stalk color above ring 1023.905195\\n",
#
# "2 stalk color below ring 796.235885\\n",
#
# "11 population 795.562987\\n"
#
# \],
#
# "name": "stdout"
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 436
#
# },
#
# "id": "DQRy4JLh23C4",
#
# "outputId": "a11a59ee-38c2-461b-b5ce-544be0595e31"
#
# },
#
# "source": \[
#
# "\#MODEL BUILDING\\n",
#
# "new\_x = k\[\['gill-color', 'ring-type' , 'stalk-root', 'stalk color
# above ring' , 'stalk color below ring' , 'population'\]\]\\n",
#
# "new\_x"
#
# \],
#
# "execution\_count": 221,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>gill-color\</th\>\\n",
#
# " \<th\>ring-type\</th\>\\n",
#
# " \<th\>stalk-root\</th\>\\n",
#
# " \<th\>stalk color above ring\</th\>\\n",
#
# " \<th\>stalk color below ring\</th\>\\n",
#
# " \<th\>population\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>0\</th\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>1\</th\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>2\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>3\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>4\</th\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>3\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>...\</th\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \<td\>...\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8119\</th\>\\n",
#
# " \<td\>11\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8120\</th\>\\n",
#
# " \<td\>11\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8121\</th\>\\n",
#
# " \<td\>5\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8122\</th\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>8123\</th\>\\n",
#
# " \<td\>11\</td\>\\n",
#
# " \<td\>4\</td\>\\n",
#
# " \<td\>0\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>2\</td\>\\n",
#
# " \<td\>1\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\<p\>8124 rows × 6 columns\</p\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " gill-color ring-type ... stalk color below ring population\\n",
#
# "0 4 4 ... 2 3\\n",
#
# "1 4 4 ... 2 2\\n",
#
# "2 5 4 ... 2 2\\n",
#
# "3 5 4 ... 2 3\\n",
#
# "4 4 0 ... 2 0\\n",
#
# "... ... ... ... ... ...\\n",
#
# "8119 11 4 ... 2 1\\n",
#
# "8120 11 4 ... 2 4\\n",
#
# "8121 5 4 ... 2 1\\n",
#
# "8122 0 0 ... 1 4\\n",
#
# "8123 11 4 ... 2 1\\n",
#
# "\\n",
#
# "\[8124 rows x 6 columns\]"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 221
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "3OReu9Xg4xwU"
#
# },
#
# "source": \[
#
# "\#Applying standardscaler to top 6 features\\n",
#
# "scalar =StandardScaler()\\n",
#
# "\\n",
#
# "x\_scalar = scalar.fit\_transform(new\_x)\\n"
#
# \],
#
# "execution\_count": 222,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "xR\_70hmr6uOZ",
#
# "outputId": "01f1dfca-947c-423f-962f-2cf9df71edc9"
#
# },
#
# "source": \[
#
# "x\_scalar"
#
# \],
#
# "execution\_count": 220,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[\[-0.22899776, 0.94808086, 1.78146019, 0.68377765,
# 0.58638466,\\n",
#
# " -0.5143892 \],\\n",
#
# " \[-0.22899776, 0.94808086, 0.83898933, 0.68377765, 0.58638466,\\n",
#
# " -1.31310821\],\\n",
#
# " \[ 0.05347685, 0.94808086, 0.83898933, 0.68377765, 0.58638466,\\n",
#
# " -1.31310821\],\\n",
#
# " ...,\\n",
#
# " \[ 0.05347685, 0.94808086, -1.0459524 , 0.68377765, 0.58638466,\\n",
#
# " -2.11182722\],\\n",
#
# " \[-1.35889624, -1.27221574, -1.0459524 , 0.68377765, -0.89305291,\\n",
#
# " 0.28432981\],\\n",
#
# " \[ 1.74832457, 0.94808086, -1.0459524 , 0.68377765, 0.58638466,\\n",
#
# " -2.11182722\]\])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 220
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "Hy9sxmNj6y5L"
#
# },
#
# "source": \[
#
# "\#Building model to test unexposed data\\n",
#
# "\\n",
#
# "x\_train, x\_test, y\_train, y\_test = train\_test\_split(x\_scalar, y,
# test\_size = 0.25, random\_state = 35)\\n",
#
# "\\n",
#
# "knn = KNeighborsClassifier()\\n",
#
# "knn.fit(x\_train, y\_train)\\n",
#
# "y\_pred = knn.predict(x\_test)"
#
# \],
#
# "execution\_count": 223,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "Y-Ef7eNy7iEW",
#
# "outputId": "7f0eca49-318f-4ecf-f382-c4ea8cce1518"
#
# },
#
# "source": \[
#
# "confusion\_matrix(y\_test,y\_pred)"
#
# \],
#
# "execution\_count": 224,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[\[1070, 7\],\\n",
#
# " \[ 31, 923\]\])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 224
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "ZQ86Wtl\_7pgU",
#
# "outputId": "b2934e32-4105-407b-95d8-7899115360a2"
#
# },
#
# "source": \[
#
# "print(classification\_report(y\_test,y\_pred))"
#
# \],
#
# "execution\_count": 225,
#
# "outputs": \[
#
# {
#
# "output\_type": "stream",
#
# "text": \[
#
# " precision recall f1-score support\\n",
#
# "\\n",
#
# " 0 0.97 0.99 0.98 1077\\n",
#
# " 1 0.99 0.97 0.98 954\\n",
#
# "\\n",
#
# " accuracy 0.98 2031\\n",
#
# " macro avg 0.98 0.98 0.98 2031\\n",
#
# "weighted avg 0.98 0.98 0.98 2031\\n",
#
# "\\n"
#
# \],
#
# "name": "stdout"
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "zV\_HPE\_S7wp9",
#
# "outputId": "a3615391-21cd-4109-9f88-6070539a9ffa"
#
# },
#
# "source": \[
#
# "\#Applying cross validation technique:\\n",
#
# "\\n",
#
# "k\_f = KFold(n\_splits = 4, shuffle = True)\\n",
#
# "k\_f\\n",
#
# "\\n"
#
# \],
#
# "execution\_count": 232,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "KFold(n\_splits=4, random\_state=None, shuffle=True)"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 232
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "m9atVHH98MMe"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "-tLQFaMC97EX",
#
# "outputId": "d150e902-b1cf-4eab-9d2d-6b76cf87e2c1"
#
# },
#
# "source": \[
#
# "cross\_val\_score(knn, x\_scalar, y, cv = 5)"
#
# \],
#
# "execution\_count": 235,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "array(\[0.80246154, 0.99261538, 0.95261538, 0.92615385, 0.591133 \])"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 235
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "PO2KDV5J8LB7"
#
# },
#
# "source": \[
#
# ""
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "Am24\_sG3-akG",
#
# "outputId": "da172d6a-0ce8-46cf-d6cb-a98e6f1c8255"
#
# },
#
# "source": \[
#
# "cross\_val\_score(knn, x\_scalar, y, cv = 5).mean()"
#
# \],
#
# "execution\_count": 236,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.8529958317544525"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 236
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "4gcKaRFe-fYT"
#
# },
#
# "source": \[
#
# "\#Difference between accuracy score of knn model and its cross
# validation technique is:\\n",
#
# "knn\_diff = 0.98 - 0.8529958317544525"
#
# \],
#
# "execution\_count": 237,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/"
#
# },
#
# "id": "ROXfNX8w-\_lV",
#
# "outputId": "b16722db-bd9f-49a9-e8a5-505f6f27c48f"
#
# },
#
# "source": \[
#
# "knn\_diff"
#
# \],
#
# "execution\_count": 238,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/plain": \[
#
# "0.1270041682455475"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 238
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "CJdWUM6w\_BI1"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "47syl6StDlFA"
#
# },
#
# "source": \[
#
# "THE DIFFERENCE BETWEEN MODELS AND THE CROSS VALIDATION SCORE:\\n"
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 142
#
# },
#
# "id": "LFtYYAxQEAh\_",
#
# "outputId": "9d79c27f-c3ed-4368-f3e6-f9c5310f3b98"
#
# },
#
# "source": \[
#
# "diff = pd.DataFrame({})\\n",
#
# "diff\['ALGORITHM'\] = \['knn', 'Decision Tree', 'logistic
# regresion'\]\\n",
#
# "diff\['DIFFERENCE'\] = \[0.1270041682455475,
# 0.03233906782872298,0.027892100771886308\]\\n",
#
# "diff"
#
# \],
#
# "execution\_count": 330,
#
# "outputs": \[
#
# {
#
# "output\_type": "execute\_result",
#
# "data": {
#
# "text/html": \[
#
# "\<div\>\\n",
#
# "\<style scoped\>\\n",
#
# " .dataframe tbody tr th:only-of-type {\\n",
#
# " vertical-align: middle;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe tbody tr th {\\n",
#
# " vertical-align: top;\\n",
#
# " }\\n",
#
# "\\n",
#
# " .dataframe thead th {\\n",
#
# " text-align: right;\\n",
#
# " }\\n",
#
# "\</style\>\\n",
#
# "\<table border=\\"1\\" class=\\"dataframe\\"\>\\n",
#
# " \<thead\>\\n",
#
# " \<tr style=\\"text-align: right;\\"\>\\n",
#
# " \<th\>\</th\>\\n",
#
# " \<th\>ALGORITHM\</th\>\\n",
#
# " \<th\>DIFFERENCE\</th\>\\n",
#
# " \</tr\>\\n",
#
# " \</thead\>\\n",
#
# " \<tbody\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>0\</th\>\\n",
#
# " \<td\>knn\</td\>\\n",
#
# " \<td\>0.127004\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>1\</th\>\\n",
#
# " \<td\>Decision Tree\</td\>\\n",
#
# " \<td\>0.032339\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \<tr\>\\n",
#
# " \<th\>2\</th\>\\n",
#
# " \<td\>logistic regresion\</td\>\\n",
#
# " \<td\>0.027892\</td\>\\n",
#
# " \</tr\>\\n",
#
# " \</tbody\>\\n",
#
# "\</table\>\\n",
#
# "\</div\>"
#
# \],
#
# "text/plain": \[
#
# " ALGORITHM DIFFERENCE\\n",
#
# "0 knn 0.127004\\n",
#
# "1 Decision Tree 0.032339\\n",
#
# "2 logistic regresion 0.027892"
#
# \]
#
# },
#
# "metadata": {
#
# "tags": \[\]
#
# },
#
# "execution\_count": 330
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "wEXpgBm1E6sl"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "markdown",
#
# "metadata": {
#
# "id": "of2T3\_tdGNeH"
#
# },
#
# "source": \[
#
# "As the distance is minimum in case of logistic regression, we will use
# logistic regression for the hyperparameter tuning."
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "hiI8WtfHGXqQ"
#
# },
#
# "source": \[
#
# "\#importing libraries\\n",
#
# "from sklearn import linear\_model,decomposition, datasets\\n",
#
# "from sklearn.pipeline import Pipeline\\n",
#
# "from sklearn.model\_selection import GridSearchCV\\n",
#
# "from sklearn.preprocessing import StandardScaler"
#
# \],
#
# "execution\_count": 332,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "C2MWyjcyOMMz"
#
# },
#
# "source": \[
#
# "\#defining the variables:\\n",
#
# "\\n",
#
# "X = i\\n",
#
# "y = y "
#
# \],
#
# "execution\_count": 333,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "DJI\_1B2ROg3X"
#
# },
#
# "source": \[
#
# "\#We will use standard scalar and PCA"
#
# \],
#
# "execution\_count": 337,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "dipIlCXSOhtf"
#
# },
#
# "source": \[
#
# "st\_sc = StandardScaler()"
#
# \],
#
# "execution\_count": 339,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "8qfE-1dXO5XT"
#
# },
#
# "source": \[
#
# "pca = decomposition.PCA()"
#
# \],
#
# "execution\_count": 342,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "iXQF56fVPSM9"
#
# },
#
# "source": \[
#
# "logistic\_reg = linear\_model.LogisticRegression"
#
# \],
#
# "execution\_count": 343,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "M\_Cjv5bCPip9"
#
# },
#
# "source": \[
#
# "\#We will use pipeline for GridSearchCV"
#
# \],
#
# "execution\_count": 344,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "tUkTKBwHPqmF"
#
# },
#
# "source": \[
#
# "pipe = Pipeline(steps =
# \[('st\_sc',st\_sc),('pca',pca),('log\_reg',logistic\_reg)\])"
#
# \],
#
# "execution\_count": 346,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "q-bXuZsbQFzv"
#
# },
#
# "source": \[
#
# "n\_components = list(range(1,X.shape\[1\]+1,1))"
#
# \],
#
# "execution\_count": 347,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "gKtC8evkQcgs"
#
# },
#
# "source": \[
#
# "C = np.logspace(-4,4,50)\\n",
#
# "penalty = \['l1','l2'\]"
#
# \],
#
# "execution\_count": 359,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "79aN8dTOQ0-X"
#
# },
#
# "source": \[
#
# "parameters = dict (pca\_\_n\_components = n\_components,\\n",
#
# " logistic\_reg\_\_C = C,\\n",
#
# " logistic\_reg\_\_penalty = penalty)"
#
# \],
#
# "execution\_count": 360,
#
# "outputs": \[\]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 323
#
# },
#
# "id": "aq-WqxSlRLUI",
#
# "outputId": "fe5f2720-c17d-48f6-8051-73990fb0819b"
#
# },
#
# "source": \[
#
# "clf\_GS = GridSearchCV(pipe,parameters)\\n",
#
# "clf\_GS.fit(X, y)"
#
# \],
#
# "execution\_count": 362,
#
# "outputs": \[
#
# {
#
# "output\_type": "error",
#
# "ename": "TypeError",
#
# "evalue": "ignored",
#
# "traceback": \[
#
# "\\u001b\[0;31m---------------------------------------------------------------------------\\u001b\[0m",
#
# "\\u001b\[0;31mTypeError\\u001b\[0m Traceback (most recent call last)",
#
# "\\u001b\[0;32m\<ipython-input-362-eaa1010ae368\>\\u001b\[0m in
# \\u001b\[0;36m\<module\>\\u001b\[0;34m()\\u001b\[0m\\n\\u001b\[1;32m
# 1\\u001b\[0m \\u001b\[0mclf\_GS\\u001b\[0m \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mGridSearchCV\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mpipe\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m\\u001b\[0mparameters\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m----\>
# 2\\u001b\[0;31m
# \\u001b\[0mclf\_GS\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mfit\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mX\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0my\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/model\_selection/\_search.py\\u001b\[0m
# in \\u001b\[0;36mfit\\u001b\[0;34m(self, X, y, groups,
# \*\*fit\_params)\\u001b\[0m\\n\\u001b\[1;32m 708\\u001b\[0m
# \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0mresults\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 709\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m--\>
# 710\\u001b\[0;31m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_run\_search\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mevaluate\_candidates\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 711\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 712\\u001b\[0m \\u001b\[0;31m\# For multi-metric evaluation, store the
# best\_index\_, best\_params\_
# and\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/model\_selection/\_search.py\\u001b\[0m
# in \\u001b\[0;36m\_run\_search\\u001b\[0;34m(self,
# evaluate\_candidates)\\u001b\[0m\\n\\u001b\[1;32m 1149\\u001b\[0m
# \\u001b\[0;32mdef\\u001b\[0m
# \\u001b\[0m\_run\_search\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mevaluate\_candidates\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 1150\\u001b\[0m \\u001b\[0;34m\\"\\"\\"Search all candidates in
# param\_grid\\"\\"\\"\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m-\>
# 1151\\u001b\[0;31m
# \\u001b\[0mevaluate\_candidates\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mParameterGrid\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mparam\_grid\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 1152\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 1153\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/model\_selection/\_search.py\\u001b\[0m
# in
# \\u001b\[0;36mevaluate\_candidates\\u001b\[0;34m(candidate\_params)\\u001b\[0m\\n\\u001b\[1;32m
# 687\\u001b\[0m \\u001b\[0;32mfor\\u001b\[0m
# \\u001b\[0mparameters\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0;34m(\\u001b\[0m\\u001b\[0mtrain\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mtest\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 688\\u001b\[0m in product(candidate\_params,\\n\\u001b\[0;32m--\>
# 689\\u001b\[0;31m cv.split(X, y, groups)))\\n\\u001b\[0m\\u001b\[1;32m
# 690\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 691\\u001b\[0m \\u001b\[0;32mif\\u001b\[0m
# \\u001b\[0mlen\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mout\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m
# \\u001b\[0;34m\<\\u001b\[0m
# \\u001b\[0;36m1\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/joblib/parallel.py\\u001b\[0m
# in \\u001b\[0;36m\_\_call\_\_\\u001b\[0;34m(self,
# iterable)\\u001b\[0m\\n\\u001b\[1;32m 1039\\u001b\[0m \\u001b\[0;31m\#
# remaining
# jobs.\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 1040\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_iterating\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0;32mFalse\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m-\>
# 1041\\u001b\[0;31m \\u001b\[0;32mif\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mdispatch\_one\_batch\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0miterator\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 1042\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_iterating\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_original\_iterator\\u001b\[0m
# \\u001b\[0;32mis\\u001b\[0m \\u001b\[0;32mnot\\u001b\[0m
# \\u001b\[0;32mNone\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 1043\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/joblib/parallel.py\\u001b\[0m
# in \\u001b\[0;36mdispatch\_one\_batch\\u001b\[0;34m(self,
# iterator)\\u001b\[0m\\n\\u001b\[1;32m 857\\u001b\[0m
# \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0;32mFalse\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 858\\u001b\[0m
# \\u001b\[0;32melse\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m--\>
# 859\\u001b\[0;31m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_dispatch\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mtasks\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 860\\u001b\[0m \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0;32mTrue\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 861\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/joblib/parallel.py\\u001b\[0m
# in \\u001b\[0;36m\_dispatch\\u001b\[0;34m(self,
# batch)\\u001b\[0m\\n\\u001b\[1;32m 775\\u001b\[0m
# \\u001b\[0;32mwith\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_lock\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 776\\u001b\[0m \\u001b\[0mjob\_idx\\u001b\[0m \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mlen\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_jobs\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m--\>
# 777\\u001b\[0;31m \\u001b\[0mjob\\u001b\[0m \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_backend\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mapply\_async\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mbatch\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mcallback\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0mcb\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 778\\u001b\[0m \\u001b\[0;31m\# A job can complete so quickly than its
# callback
# is\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 779\\u001b\[0m \\u001b\[0;31m\# called before we get here, causing
# self.\_jobs
# to\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/joblib/\_parallel\_backends.py\\u001b\[0m
# in \\u001b\[0;36mapply\_async\\u001b\[0;34m(self, func,
# callback)\\u001b\[0m\\n\\u001b\[1;32m 206\\u001b\[0m
# \\u001b\[0;32mdef\\u001b\[0m
# \\u001b\[0mapply\_async\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mfunc\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mcallback\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0;32mNone\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 207\\u001b\[0m \\u001b\[0;34m\\"\\"\\"Schedule a func to be
# run\\"\\"\\"\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m--\>
# 208\\u001b\[0;31m \\u001b\[0mresult\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mImmediateResult\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mfunc\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 209\\u001b\[0m \\u001b\[0;32mif\\u001b\[0m
# \\u001b\[0mcallback\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 210\\u001b\[0m
# \\u001b\[0mcallback\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mresult\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/joblib/\_parallel\_backends.py\\u001b\[0m
# in \\u001b\[0;36m\_\_init\_\_\\u001b\[0;34m(self,
# batch)\\u001b\[0m\\n\\u001b\[1;32m 570\\u001b\[0m \\u001b\[0;31m\# Don't
# delay the application, to avoid keeping the
# input\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 571\\u001b\[0m \\u001b\[0;31m\# arguments in
# memory\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m--\>
# 572\\u001b\[0;31m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mresults\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mbatch\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 573\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 574\\u001b\[0m \\u001b\[0;32mdef\\u001b\[0m
# \\u001b\[0mget\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/joblib/parallel.py\\u001b\[0m
# in
# \\u001b\[0;36m\_\_call\_\_\\u001b\[0;34m(self)\\u001b\[0m\\n\\u001b\[1;32m
# 261\\u001b\[0m \\u001b\[0;32mwith\\u001b\[0m
# \\u001b\[0mparallel\_backend\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_backend\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mn\_jobs\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_n\_jobs\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 262\\u001b\[0m return \[func(\*args, \*\*kwargs)\\n\\u001b\[0;32m--\>
# 263\\u001b\[0;31m for func, args, kwargs in
# self.items\]\\n\\u001b\[0m\\u001b\[1;32m 264\\u001b\[0m
# \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m 265\\u001b\[0m
# \\u001b\[0;32mdef\\u001b\[0m
# \\u001b\[0m\_\_reduce\_\_\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/joblib/parallel.py\\u001b\[0m
# in
# \\u001b\[0;36m\<listcomp\>\\u001b\[0;34m(.0)\\u001b\[0m\\n\\u001b\[1;32m
# 261\\u001b\[0m \\u001b\[0;32mwith\\u001b\[0m
# \\u001b\[0mparallel\_backend\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_backend\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mn\_jobs\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_n\_jobs\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 262\\u001b\[0m return \[func(\*args, \*\*kwargs)\\n\\u001b\[0;32m--\>
# 263\\u001b\[0;31m for func, args, kwargs in
# self.items\]\\n\\u001b\[0m\\u001b\[1;32m 264\\u001b\[0m
# \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m 265\\u001b\[0m
# \\u001b\[0;32mdef\\u001b\[0m
# \\u001b\[0m\_\_reduce\_\_\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/model\_selection/\_validation.py\\u001b\[0m
# in \\u001b\[0;36m\_fit\_and\_score\\u001b\[0;34m(estimator, X, y,
# scorer, train, test, verbose, parameters, fit\_params,
# return\_train\_score, return\_parameters, return\_n\_test\_samples,
# return\_times, return\_estimator,
# error\_score)\\u001b\[0m\\n\\u001b\[1;32m 502\\u001b\[0m
# \\u001b\[0mcloned\_parameters\\u001b\[0m\\u001b\[0;34m\[\\u001b\[0m\\u001b\[0mk\\u001b\[0m\\u001b\[0;34m\]\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mclone\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mv\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0msafe\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0;32mFalse\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 503\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m--\>
# 504\\u001b\[0;31m \\u001b\[0mestimator\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mestimator\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mset\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m\*\*\\u001b\[0m\\u001b\[0mcloned\_parameters\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 505\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 506\\u001b\[0m \\u001b\[0mstart\_time\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mtime\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mtime\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py\\u001b\[0m
# in \\u001b\[0;36mset\_params\\u001b\[0;34m(self,
# \*\*kwargs)\\u001b\[0m\\n\\u001b\[1;32m 161\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 162\\u001b\[0m \\"\\"\\"\\n\\u001b\[0;32m--\> 163\\u001b\[0;31m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_set\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m'steps'\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0;34m\*\*\\u001b\[0m\\u001b\[0mkwargs\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 164\\u001b\[0m \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 165\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/utils/metaestimators.py\\u001b\[0m
# in \\u001b\[0;36m\_set\_params\\u001b\[0;34m(self, attr,
# \*\*params)\\u001b\[0m\\n\\u001b\[1;32m 48\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_replace\_estimator\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mattr\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mname\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mparams\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mpop\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mname\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 49\\u001b\[0m \\u001b\[0;31m\# 3. Step parameters and other
# initialisation
# arguments\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m---\>
# 50\\u001b\[0;31m
# \\u001b\[0msuper\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mset\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m\*\*\\u001b\[0m\\u001b\[0mparams\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 51\\u001b\[0m \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 52\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/base.py\\u001b\[0m
# in \\u001b\[0;36mset\_params\\u001b\[0;34m(self,
# \*\*params)\\u001b\[0m\\n\\u001b\[1;32m 225\\u001b\[0m \\u001b\[0;31m\#
# Simple optimization to gain speed (inspect is
# slow)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 226\\u001b\[0m \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m--\>
# 227\\u001b\[0;31m \\u001b\[0mvalid\_params\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mget\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mdeep\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0;32mTrue\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 228\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 229\\u001b\[0m \\u001b\[0mnested\_params\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mdefaultdict\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mdict\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m
# \\u001b\[0;31m\# grouped by
# prefix\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/pipeline.py\\u001b\[0m
# in \\u001b\[0;36mget\_params\\u001b\[0;34m(self,
# deep)\\u001b\[0m\\n\\u001b\[1;32m 150\\u001b\[0m
# \\u001b\[0mParameter\\u001b\[0m \\u001b\[0mnames\\u001b\[0m
# \\u001b\[0mmapped\\u001b\[0m \\u001b\[0mto\\u001b\[0m
# \\u001b\[0mtheir\\u001b\[0m
# \\u001b\[0mvalues\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 151\\u001b\[0m \\"\\"\\"\\n\\u001b\[0;32m--\> 152\\u001b\[0;31m
# \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0mself\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0m\_get\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m'steps'\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mdeep\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0mdeep\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 153\\u001b\[0m \\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 154\\u001b\[0m \\u001b\[0;32mdef\\u001b\[0m
# \\u001b\[0mset\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mself\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0;34m\*\*\\u001b\[0m\\u001b\[0mkwargs\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;32m/usr/local/lib/python3.7/dist-packages/sklearn/utils/metaestimators.py\\u001b\[0m
# in \\u001b\[0;36m\_get\_params\\u001b\[0;34m(self, attr,
# deep)\\u001b\[0m\\n\\u001b\[1;32m 30\\u001b\[0m
# \\u001b\[0;32mfor\\u001b\[0m
# \\u001b\[0mname\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mestimator\\u001b\[0m \\u001b\[0;32min\\u001b\[0m
# \\u001b\[0mestimators\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 31\\u001b\[0m \\u001b\[0;32mif\\u001b\[0m
# \\u001b\[0mhasattr\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mestimator\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0;34m'get\_params'\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0;32m---\>
# 32\\u001b\[0;31m \\u001b\[0;32mfor\\u001b\[0m
# \\u001b\[0mkey\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mvalue\\u001b\[0m \\u001b\[0;32min\\u001b\[0m
# \\u001b\[0mestimator\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mget\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0mdeep\\u001b\[0m\\u001b\[0;34m=\\u001b\[0m\\u001b\[0;32mTrue\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mitems\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m:\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m\\u001b\[1;32m
# 33\\u001b\[0m
# \\u001b\[0mout\\u001b\[0m\\u001b\[0;34m\[\\u001b\[0m\\u001b\[0;34m'%s\_\_%s'\\u001b\[0m
# \\u001b\[0;34m%\\u001b\[0m
# \\u001b\[0;34m(\\u001b\[0m\\u001b\[0mname\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m
# \\u001b\[0mkey\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\]\\u001b\[0m
# \\u001b\[0;34m=\\u001b\[0m
# \\u001b\[0mvalue\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[1;32m
# 34\\u001b\[0m \\u001b\[0;32mreturn\\u001b\[0m
# \\u001b\[0mout\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n",
#
# "\\u001b\[0;31mTypeError\\u001b\[0m: get\_params() missing 1 required
# positional argument: 'self'"
#
# \]
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "colab": {
#
# "base\_uri": "https://localhost:8080/",
#
# "height": 163
#
# },
#
# "id": "okbxE2yORXTX",
#
# "outputId": "03e59304-0827-4ed3-9b97-2c40c10659d0"
#
# },
#
# "source": \[
#
# "print('best
# penalty:',clf\_GS.best\_estimator\_.get\_params()\['logistic\_reg\_\_penalty'\])"
#
# \],
#
# "execution\_count": 354,
#
# "outputs": \[
#
# {
#
# "output\_type": "error",
#
# "ename": "AttributeError",
#
# "evalue": "ignored",
#
# "traceback": \[
#
# "\\u001b\[0;31m---------------------------------------------------------------------------\\u001b\[0m",
#
# "\\u001b\[0;31mAttributeError\\u001b\[0m Traceback (most recent call
# last)",
#
# "\\u001b\[0;32m\<ipython-input-354-5bb0b7073355\>\\u001b\[0m in
# \\u001b\[0;36m\<module\>\\u001b\[0;34m()\\u001b\[0m\\n\\u001b\[0;32m----\>
# 1\\u001b\[0;31m
# \\u001b\[0mprint\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m'best
# penalty:'\\u001b\[0m\\u001b\[0;34m,\\u001b\[0m\\u001b\[0mclf\_GS\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mbest\_estimator\_\\u001b\[0m\\u001b\[0;34m.\\u001b\[0m\\u001b\[0mget\_params\\u001b\[0m\\u001b\[0;34m(\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\[\\u001b\[0m\\u001b\[0;34m'logistic\_reg\_\_penalty'\\u001b\[0m\\u001b\[0;34m\]\\u001b\[0m\\u001b\[0;34m)\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0;34m\\u001b\[0m\\u001b\[0m\\n\\u001b\[0m",
#
# "\\u001b\[0;31mAttributeError\\u001b\[0m: 'GridSearchCV' object has no
# attribute 'best\_estimator\_'"
#
# \]
#
# }
#
# \]
#
# },
#
# {
#
# "cell\_type": "code",
#
# "metadata": {
#
# "id": "eS3mdylSSlCx"
#
# },
#
# "source": \[
#
# ""
#
# \],
#
# "execution\_count": null,
#
# "outputs": \[\]
#
# }
#
# \]
#
# }
